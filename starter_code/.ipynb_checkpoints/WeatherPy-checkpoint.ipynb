# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 564

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'http://api.openweathermap.org/data/2.5/weather?'


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | lihue
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | quellon
# Processing Record 6 of Set 1 | tibiri
# Processing Record 7 of Set 1 | kurchatov
# Processing Record 8 of Set 1 | bulakamba
# Processing Record 9 of Set 1 | flying fish cove
# Processing Record 10 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 1 | haenam
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 14 of Set 1 | petrovsk-zabaykal'skiy
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | puerto natales
# Processing Record 17 of Set 1 | bubaque
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | howrah
# Processing Record 20 of Set 1 | edinburgh of the seven seas
# Processing Record 21 of Set 1 | matoury
# Processing Record 22 of Set 1 | coquimbo
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | hawaiian paradise park
# Processing Record 27 of Set 1 | canutama
# Processing Record 28 of Set 1 | lichtenburg
# Processing Record 29 of Set 1 | adamstown
# Processing Record 30 of Set 1 | moyynkum
# Processing Record 31 of Set 1 | portland
# Processing Record 32 of Set 1 | selfoss
# Processing Record 33 of Set 1 | winejok
# City not found. Skipping...
# Processing Record 34 of Set 1 | mahdia
# Processing Record 35 of Set 1 | nizhnyaya tura
# Processing Record 36 of Set 1 | qurayyat
# Processing Record 37 of Set 1 | kavieng
# Processing Record 38 of Set 1 | lorengau
# Processing Record 39 of Set 1 | nushki
# Processing Record 40 of Set 1 | fort mcmurray
# Processing Record 41 of Set 1 | remire-montjoly
# Processing Record 42 of Set 1 | gadzhiyevo
# Processing Record 43 of Set 1 | port mathurin
# Processing Record 44 of Set 1 | chifeng
# Processing Record 45 of Set 1 | costa teguise
# City not found. Skipping...
# Processing Record 46 of Set 1 | namibe
# Processing Record 47 of Set 1 | buurhakaba
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | papatowai
# Processing Record 50 of Set 1 | qaqortoq
# Processing Record 0 of Set 2 | salekhard
# Processing Record 1 of Set 2 | kayar
# Processing Record 2 of Set 2 | pandan
# Processing Record 3 of Set 2 | mugia
# Processing Record 4 of Set 2 | monroeville
# Processing Record 5 of Set 2 | invercargill
# Processing Record 6 of Set 2 | badger
# Processing Record 7 of Set 2 | whitehorse
# Processing Record 8 of Set 2 | olonkinbyen
# Processing Record 9 of Set 2 | happy valley-goose bay
# Processing Record 10 of Set 2 | hamilton
# Processing Record 11 of Set 2 | stanley
# Processing Record 12 of Set 2 | mandiana
# Processing Record 13 of Set 2 | tazovsky
# Processing Record 14 of Set 2 | codrington
# Processing Record 15 of Set 2 | amahai
# Processing Record 16 of Set 2 | ancud
# Processing Record 17 of Set 2 | laguna
# Processing Record 18 of Set 2 | enewetak
# Processing Record 19 of Set 2 | ust-nera
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | walvis bay
# Processing Record 22 of Set 2 | magadan
# Processing Record 23 of Set 2 | saint-pierre
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | wailua homesteads
# Processing Record 26 of Set 2 | iskateley
# Processing Record 27 of Set 2 | tres arroyos
# Processing Record 28 of Set 2 | ahau
# City not found. Skipping...
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | arteche
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | curuzu cuatia
# Processing Record 33 of Set 2 | seryshevo
# Processing Record 34 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | tshabong
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | kismayo
# Processing Record 39 of Set 2 | margaret river
# Processing Record 40 of Set 2 | malango
# Processing Record 41 of Set 2 | rongelap
# Processing Record 42 of Set 2 | mahina
# Processing Record 43 of Set 2 | vorgashor
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | uturoa
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | alice springs
# Processing Record 48 of Set 2 | hasaki
# Processing Record 49 of Set 2 | terme
# Processing Record 0 of Set 3 | yellowknife
# Processing Record 1 of Set 3 | talara
# Processing Record 2 of Set 3 | blackmans bay
# Processing Record 3 of Set 3 | champerico
# Processing Record 4 of Set 3 | bamboo flat
# Processing Record 5 of Set 3 | bilibino
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | chernyshevskiy
# Processing Record 9 of Set 3 | taltal
# Processing Record 10 of Set 3 | lata
# Processing Record 11 of Set 3 | price
# Processing Record 12 of Set 3 | mariental
# Processing Record 13 of Set 3 | udachny
# Processing Record 14 of Set 3 | tomohon
# Processing Record 15 of Set 3 | es castell
# Processing Record 16 of Set 3 | constantia
# Processing Record 17 of Set 3 | flin flon
# Processing Record 18 of Set 3 | st. john's
# Processing Record 19 of Set 3 | monrovia
# Processing Record 20 of Set 3 | lebu
# Processing Record 21 of Set 3 | galle
# Processing Record 22 of Set 3 | pueblo
# Processing Record 23 of Set 3 | kotabumi
# Processing Record 24 of Set 3 | buinsk
# Processing Record 25 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 26 of Set 3 | chibougamau
# Processing Record 27 of Set 3 | san antonio de pale
# Processing Record 28 of Set 3 | mount isa
# Processing Record 29 of Set 3 | haiku-pauwela
# Processing Record 30 of Set 3 | kyabe
# Processing Record 31 of Set 3 | raduzhnyy
# Processing Record 32 of Set 3 | ust'-ilimsk
# Processing Record 33 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 34 of Set 3 | saipan
# Processing Record 35 of Set 3 | west island
# Processing Record 36 of Set 3 | atafu village
# Processing Record 37 of Set 3 | ola
# Processing Record 38 of Set 3 | zaozersk
# Processing Record 39 of Set 3 | andovoranto
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | hobyo
# Processing Record 42 of Set 3 | labrador city
# Processing Record 43 of Set 3 | utrik
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | plastun
# Processing Record 46 of Set 3 | tavda
# Processing Record 47 of Set 3 | isafjordur
# Processing Record 48 of Set 3 | port moresby
# Processing Record 49 of Set 3 | ikwiriri
# Processing Record 0 of Set 4 | nova sintra
# Processing Record 1 of Set 4 | pontes e lacerda
# Processing Record 2 of Set 4 | ushuaia
# Processing Record 3 of Set 4 | tsiombe
# Processing Record 4 of Set 4 | kavaratti
# Processing Record 5 of Set 4 | abdanan
# Processing Record 6 of Set 4 | college
# Processing Record 7 of Set 4 | dunedin
# Processing Record 8 of Set 4 | harstad
# Processing Record 9 of Set 4 | al ghayzah
# Processing Record 10 of Set 4 | avarua
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | brookings
# Processing Record 13 of Set 4 | cam ranh
# Processing Record 14 of Set 4 | balkashino
# Processing Record 15 of Set 4 | boquira
# Processing Record 16 of Set 4 | al majaridah
# Processing Record 17 of Set 4 | gondar
# Processing Record 18 of Set 4 | kone
# Processing Record 19 of Set 4 | tara
# Processing Record 20 of Set 4 | mathba
# Processing Record 21 of Set 4 | floro
# Processing Record 22 of Set 4 | burao
# Processing Record 23 of Set 4 | checker hall
# City not found. Skipping...
# Processing Record 24 of Set 4 | griffith
# Processing Record 25 of Set 4 | smithers
# Processing Record 26 of Set 4 | airuk
# Processing Record 27 of Set 4 | yulinshi
# Processing Record 28 of Set 4 | kimbe
# Processing Record 29 of Set 4 | ushtobe
# Processing Record 30 of Set 4 | kodiak
# Processing Record 31 of Set 4 | mount gambier
# Processing Record 32 of Set 4 | east london
# Processing Record 33 of Set 4 | afaahiti
# Processing Record 34 of Set 4 | praia da vitoria
# Processing Record 35 of Set 4 | tobi village
# City not found. Skipping...
# Processing Record 36 of Set 4 | kitimat
# Processing Record 37 of Set 4 | nar'yan-mar
# Processing Record 38 of Set 4 | ishigaki
# Processing Record 39 of Set 4 | pisco
# Processing Record 40 of Set 4 | isangel
# Processing Record 41 of Set 4 | kristiansund
# Processing Record 42 of Set 4 | revda
# Processing Record 43 of Set 4 | aasiaat
# Processing Record 44 of Set 4 | reggane
# Processing Record 45 of Set 4 | nizhnyaya poyma
# Processing Record 46 of Set 4 | noosa heads
# Processing Record 47 of Set 4 | mili
# Processing Record 48 of Set 4 | zouerate
# Processing Record 49 of Set 4 | kharabali
# Processing Record 0 of Set 5 | kayangel
# Processing Record 1 of Set 5 | taourirt
# Processing Record 2 of Set 5 | port macquarie
# Processing Record 3 of Set 5 | barakani
# Processing Record 4 of Set 5 | queenstown
# Processing Record 5 of Set 5 | extrema
# Processing Record 6 of Set 5 | dhidhdhoo
# Processing Record 7 of Set 5 | kingston
# Processing Record 8 of Set 5 | santa cruz del sur
# Processing Record 9 of Set 5 | qacha's nek
# Processing Record 10 of Set 5 | pran buri
# Processing Record 11 of Set 5 | plettenberg bay
# Processing Record 12 of Set 5 | kani keli
# Processing Record 13 of Set 5 | brisas de zicatela
# Processing Record 14 of Set 5 | honefoss
# Processing Record 15 of Set 5 | touros
# Processing Record 16 of Set 5 | san juan
# Processing Record 17 of Set 5 | luau
# Processing Record 18 of Set 5 | pirai do sul
# Processing Record 19 of Set 5 | banfora
# Processing Record 20 of Set 5 | ha'il
# Processing Record 21 of Set 5 | chiras
# Processing Record 22 of Set 5 | el molar
# Processing Record 23 of Set 5 | fukuecho
# Processing Record 24 of Set 5 | woodward
# Processing Record 25 of Set 5 | madang
# Processing Record 26 of Set 5 | eupen
# Processing Record 27 of Set 5 | qusmuryn
# Processing Record 28 of Set 5 | egilsstadir
# Processing Record 29 of Set 5 | papao
# Processing Record 30 of Set 5 | susuman
# Processing Record 31 of Set 5 | tommot
# Processing Record 32 of Set 5 | mulayjah
# Processing Record 33 of Set 5 | akalgarh
# Processing Record 34 of Set 5 | keflavik
# Processing Record 35 of Set 5 | guntakal junction
# Processing Record 36 of Set 5 | yanam
# Processing Record 37 of Set 5 | tsumeb
# Processing Record 38 of Set 5 | weiser
# Processing Record 39 of Set 5 | taoudenni
# Processing Record 40 of Set 5 | palmer
# Processing Record 41 of Set 5 | sur
# Processing Record 42 of Set 5 | yoichi
# Processing Record 43 of Set 5 | trairi
# Processing Record 44 of Set 5 | kachug
# Processing Record 45 of Set 5 | naracoorte
# Processing Record 46 of Set 5 | ghanzi
# Processing Record 47 of Set 5 | kenora
# Processing Record 48 of Set 5 | weno
# Processing Record 49 of Set 5 | abadeh
# Processing Record 0 of Set 6 | coremas
# Processing Record 1 of Set 6 | kourou
# Processing Record 2 of Set 6 | punta arenas
# Processing Record 3 of Set 6 | mar del plata
# Processing Record 4 of Set 6 | mouila
# Processing Record 5 of Set 6 | amga
# Processing Record 6 of Set 6 | petoskey
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | lastoursville
# Processing Record 9 of Set 6 | greenville
# Processing Record 10 of Set 6 | kiunga
# Processing Record 11 of Set 6 | sao vicente
# Processing Record 12 of Set 6 | hirara
# Processing Record 13 of Set 6 | kangding
# Processing Record 14 of Set 6 | la passe
# Processing Record 15 of Set 6 | hithadhoo
# Processing Record 16 of Set 6 | nuevo imperial
# Processing Record 17 of Set 6 | dabakala
# Processing Record 18 of Set 6 | hadibu
# Processing Record 19 of Set 6 | karratha
# Processing Record 20 of Set 6 | berdigestyakh
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | anadyr
# Processing Record 23 of Set 6 | i-n-salah
# Processing Record 24 of Set 6 | midvagur
# Processing Record 25 of Set 6 | kailua-kona
# Processing Record 26 of Set 6 | ribeira brava
# Processing Record 27 of Set 6 | lazaro cardenas
# Processing Record 28 of Set 6 | nabire
# Processing Record 29 of Set 6 | trinity beach
# Processing Record 30 of Set 6 | kongolo
# Processing Record 31 of Set 6 | enriquillo
# Processing Record 32 of Set 6 | nagqu
# Processing Record 33 of Set 6 | leava
# Processing Record 34 of Set 6 | abepura
# Processing Record 35 of Set 6 | tindouf
# Processing Record 36 of Set 6 | crane
# Processing Record 37 of Set 6 | bykovo
# Processing Record 38 of Set 6 | xai-xai
# Processing Record 39 of Set 6 | huanren
# Processing Record 40 of Set 6 | el bauga
# Processing Record 41 of Set 6 | buka
# Processing Record 42 of Set 6 | yuzhno-kurilsk
# Processing Record 43 of Set 6 | khandyga
# Processing Record 44 of Set 6 | naze
# Processing Record 45 of Set 6 | grand falls-windsor
# Processing Record 46 of Set 6 | nemuro
# Processing Record 47 of Set 6 | korla
# Processing Record 48 of Set 6 | vilhena
# Processing Record 49 of Set 6 | xinyuan
# Processing Record 0 of Set 7 | vernon
# Processing Record 1 of Set 7 | colonia
# Processing Record 2 of Set 7 | salalah
# Processing Record 3 of Set 7 | camana
# Processing Record 4 of Set 7 | sumenep
# Processing Record 5 of Set 7 | zhaotong
# Processing Record 6 of Set 7 | amalfi
# Processing Record 7 of Set 7 | nantucket
# Processing Record 8 of Set 7 | sanniquellie
# Processing Record 9 of Set 7 | dudinka
# Processing Record 10 of Set 7 | tralee
# Processing Record 11 of Set 7 | vadso
# Processing Record 12 of Set 7 | yerofey pavlovich
# Processing Record 13 of Set 7 | palikir - national government center
# Processing Record 14 of Set 7 | sisimiut
# Processing Record 15 of Set 7 | katoya
# Processing Record 16 of Set 7 | richards bay
# Processing Record 17 of Set 7 | ruy barbosa
# Processing Record 18 of Set 7 | mildura
# Processing Record 19 of Set 7 | alaghsas
# Processing Record 20 of Set 7 | birjand
# Processing Record 21 of Set 7 | itaituba
# Processing Record 22 of Set 7 | cave creek
# Processing Record 23 of Set 7 | san jose temascatio
# Processing Record 24 of Set 7 | andol
# Processing Record 25 of Set 7 | maple ridge
# Processing Record 26 of Set 7 | cidade velha
# Processing Record 27 of Set 7 | ilhabela
# Processing Record 28 of Set 7 | el calafate
# Processing Record 29 of Set 7 | chinde
# Processing Record 30 of Set 7 | diego de almagro
# Processing Record 31 of Set 7 | pisz
# Processing Record 32 of Set 7 | muhlhausen
# Processing Record 33 of Set 7 | vila velha
# Processing Record 34 of Set 7 | segezha
# Processing Record 35 of Set 7 | kerikeri
# Processing Record 36 of Set 7 | luderitz
# Processing Record 37 of Set 7 | rabo de peixe
# Processing Record 38 of Set 7 | parras de la fuente
# Processing Record 39 of Set 7 | yorkton
# Processing Record 40 of Set 7 | miquelon
# Processing Record 41 of Set 7 | coyhaique
# Processing Record 42 of Set 7 | djenne
# Processing Record 43 of Set 7 | ouadda
# Processing Record 44 of Set 7 | beira
# Processing Record 45 of Set 7 | freetown
# Processing Record 46 of Set 7 | qingdao
# Processing Record 47 of Set 7 | cidreira
# Processing Record 48 of Set 7 | selkirk
# Processing Record 49 of Set 7 | lawas
# Processing Record 0 of Set 8 | hilo
# Processing Record 1 of Set 8 | kudahuvadhoo
# Processing Record 2 of Set 8 | chonchi
# Processing Record 3 of Set 8 | tura
# Processing Record 4 of Set 8 | zyryanovsk
# Processing Record 5 of Set 8 | tionk essil
# Processing Record 6 of Set 8 | nguigmi
# Processing Record 7 of Set 8 | isla vista
# Processing Record 8 of Set 8 | kisangani
# Processing Record 9 of Set 8 | kokopo
# Processing Record 10 of Set 8 | juneau
# Processing Record 11 of Set 8 | kapa'a
# Processing Record 12 of Set 8 | karlovac
# Processing Record 13 of Set 8 | pangai
# Processing Record 14 of Set 8 | araripina
# Processing Record 15 of Set 8 | dalandzadgad
# Processing Record 16 of Set 8 | gwadar
# Processing Record 17 of Set 8 | nassau
# Processing Record 18 of Set 8 | galliano
# Processing Record 19 of Set 8 | tolanaro
# Processing Record 20 of Set 8 | kapuskasing
# Processing Record 21 of Set 8 | makoua
# Processing Record 22 of Set 8 | jhalida
# Processing Record 23 of Set 8 | masterton
# Processing Record 24 of Set 8 | viedma
# Processing Record 25 of Set 8 | ciudad lazaro cardenas
# Processing Record 26 of Set 8 | polatli
# Processing Record 27 of Set 8 | vila franca do campo
# Processing Record 28 of Set 8 | chegdomyn
# Processing Record 29 of Set 8 | nishinoomote
# Processing Record 30 of Set 8 | cururupu
# Processing Record 31 of Set 8 | kendari
# Processing Record 32 of Set 8 | winnemucca
# Processing Record 33 of Set 8 | howard springs
# Processing Record 34 of Set 8 | zangguy
# City not found. Skipping...
# Processing Record 35 of Set 8 | tamanrasset
# Processing Record 36 of Set 8 | pyinmana
# Processing Record 37 of Set 8 | diebougou
# Processing Record 38 of Set 8 | mont-saint-aignan
# Processing Record 39 of Set 8 | ta`u
# Processing Record 40 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 41 of Set 8 | vallenar
# Processing Record 42 of Set 8 | intendente alvear
# Processing Record 43 of Set 8 | barentu
# Processing Record 44 of Set 8 | kotlas
# Processing Record 45 of Set 8 | stornoway
# Processing Record 46 of Set 8 | elliot lake
# Processing Record 47 of Set 8 | dryden
# Processing Record 48 of Set 8 | diu
# Processing Record 49 of Set 8 | castillos
# Processing Record 0 of Set 9 | booneville
# Processing Record 1 of Set 9 | cadale
# Processing Record 2 of Set 9 | franklin
# Processing Record 3 of Set 9 | king
# Processing Record 4 of Set 9 | al bayda'
# Processing Record 5 of Set 9 | san patricio
# Processing Record 6 of Set 9 | grove
# Processing Record 7 of Set 9 | nuuk
# Processing Record 8 of Set 9 | kyzyl-suu
# Processing Record 9 of Set 9 | north battleford
# Processing Record 10 of Set 9 | imphal
# Processing Record 11 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 12 of Set 9 | san pedro
# Processing Record 13 of Set 9 | ksar chellala
# Processing Record 14 of Set 9 | kibondo
# Processing Record 15 of Set 9 | chulym
# Processing Record 16 of Set 9 | thunder bay
# Processing Record 17 of Set 9 | crete
# Processing Record 18 of Set 9 | belyy yar
# Processing Record 19 of Set 9 | al khums
# Processing Record 20 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 21 of Set 9 | tanjung selor
# Processing Record 22 of Set 9 | orshanka
# Processing Record 23 of Set 9 | villa maria grande
# Processing Record 24 of Set 9 | mchinji
# Processing Record 25 of Set 9 | saynshand
# Processing Record 26 of Set 9 | dakoro
# Processing Record 27 of Set 9 | tezu
# Processing Record 28 of Set 9 | hami
# Processing Record 29 of Set 9 | yanchep
# Processing Record 30 of Set 9 | suva
# Processing Record 31 of Set 9 | bardai
# Processing Record 32 of Set 9 | demre
# Processing Record 33 of Set 9 | puerto baquerizo moreno
# Processing Record 34 of Set 9 | acapulco de juarez
# Processing Record 35 of Set 9 | anar darah
# Processing Record 36 of Set 9 | kyongsong
# Processing Record 37 of Set 9 | daru
# Processing Record 38 of Set 9 | mount pearl
# Processing Record 39 of Set 9 | rabaul
# Processing Record 40 of Set 9 | valjevo
# Processing Record 41 of Set 9 | mirny
# Processing Record 42 of Set 9 | baardheere
# Processing Record 43 of Set 9 | margate
# Processing Record 44 of Set 9 | pekan
# Processing Record 45 of Set 9 | dawson creek
# Processing Record 46 of Set 9 | ciudad bolivar
# Processing Record 47 of Set 9 | vuktyl
# Processing Record 48 of Set 9 | antsiranana
# Processing Record 49 of Set 9 | as sulayyil
# Processing Record 0 of Set 10 | souillac
# Processing Record 1 of Set 10 | kargopol'
# Processing Record 2 of Set 10 | eu
# City not found. Skipping...
# Processing Record 3 of Set 10 | usinsk
# Processing Record 4 of Set 10 | georgievka
# Processing Record 5 of Set 10 | turan
# Processing Record 6 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 7 of Set 10 | fale old settlement
# Processing Record 8 of Set 10 | marolambo
# Processing Record 9 of Set 10 | berezovyy
# Processing Record 10 of Set 10 | abakaliki
# Processing Record 11 of Set 10 | qal'ah-ye shahr
# Processing Record 12 of Set 10 | ebon
# Processing Record 13 of Set 10 | vilyuchinsk
# Processing Record 14 of Set 10 | sao felix do xingu
# Processing Record 15 of Set 10 | liwale
# Processing Record 16 of Set 10 | pedregal
# Processing Record 17 of Set 10 | loei
# Processing Record 18 of Set 10 | levuka
# Processing Record 19 of Set 10 | farafangana
# Processing Record 20 of Set 10 | port saint john's
# Processing Record 21 of Set 10 | lubang
# Processing Record 22 of Set 10 | lembar
# City not found. Skipping...
# Processing Record 23 of Set 10 | mogocha
# Processing Record 24 of Set 10 | hamina
# Processing Record 25 of Set 10 | rio grande
# Processing Record 26 of Set 10 | medina
# Processing Record 27 of Set 10 | anloga
# Processing Record 28 of Set 10 | paracuru
# Processing Record 29 of Set 10 | pervomayskoye
# Processing Record 30 of Set 10 | aklera
# Processing Record 31 of Set 10 | saint-hippolyte
# Processing Record 32 of Set 10 | mbanza kongo
# Processing Record 33 of Set 10 | arkadelphia
# Processing Record 34 of Set 10 | megion
# Processing Record 35 of Set 10 | callao
# Processing Record 36 of Set 10 | klyuchi
# Processing Record 37 of Set 10 | shimoda
# Processing Record 38 of Set 10 | tidjikja
# Processing Record 39 of Set 10 | guerrero negro
# Processing Record 40 of Set 10 | road town
# Processing Record 41 of Set 10 | hammerfest
# Processing Record 42 of Set 10 | baki
# Processing Record 43 of Set 10 | nova vicosa
# Processing Record 44 of Set 10 | fort bragg
# Processing Record 45 of Set 10 | assab
# Processing Record 46 of Set 10 | port-vila
# Processing Record 47 of Set 10 | las lomitas
# Processing Record 48 of Set 10 | sola
# Processing Record 49 of Set 10 | mumbwa
# Processing Record 0 of Set 11 | calingasta
# Processing Record 1 of Set 11 | san matias
# Processing Record 2 of Set 11 | melfi
# Processing Record 3 of Set 11 | caleta de carquin
# Processing Record 4 of Set 11 | yardimli
# Processing Record 5 of Set 11 | yelizovo
# Processing Record 6 of Set 11 | port isabel
# Processing Record 7 of Set 11 | jijiga
# Processing Record 8 of Set 11 | prince rupert
# Processing Record 9 of Set 11 | trevelin
# Processing Record 10 of Set 11 | kenai
# Processing Record 11 of Set 11 | balqash
# Processing Record 12 of Set 11 | taroa
# Processing Record 13 of Set 11 | ulundi
# Processing Record 14 of Set 11 | timaru
# Processing Record 15 of Set 11 | kalifornsky
# Processing Record 16 of Set 11 | errachidia
# Processing Record 17 of Set 11 | carauari
# Processing Record 18 of Set 11 | malvan
# Processing Record 19 of Set 11 | pointe-noire
# Processing Record 20 of Set 11 | buala
# Processing Record 21 of Set 11 | noumea
# Processing Record 22 of Set 11 | forster
# Processing Record 23 of Set 11 | oruro
# Processing Record 24 of Set 11 | hovd
# Processing Record 25 of Set 11 | sinabang
# Processing Record 26 of Set 11 | tortoli
# Processing Record 27 of Set 11 | mazamari
# Processing Record 28 of Set 11 | mabaruma
# Processing Record 29 of Set 11 | mberubu
# City not found. Skipping...
# Processing Record 30 of Set 11 | basco
# Processing Record 31 of Set 11 | nirmal
# Processing Record 32 of Set 11 | choyr
# Processing Record 33 of Set 11 | bechar
# Processing Record 34 of Set 11 | inhambane
# Processing Record 35 of Set 11 | mermoz boabab
# Processing Record 36 of Set 11 | lompoc
# Processing Record 37 of Set 11 | naama
# Processing Record 38 of Set 11 | arquitecto tomas romero pereira
# Processing Record 39 of Set 11 | yung shue wan
# Processing Record 40 of Set 11 | uryupinsk
# Processing Record 41 of Set 11 | juigne
# Processing Record 42 of Set 11 | huarmey
# Processing Record 43 of Set 11 | pestravka
# Processing Record 44 of Set 11 | ludres
# Processing Record 45 of Set 11 | balboa
# Processing Record 46 of Set 11 | klaksvik
# Processing Record 47 of Set 11 | ipiales
# Processing Record 48 of Set 11 | emerald
# Processing Record 49 of Set 11 | puerto deseado
# Processing Record 0 of Set 12 | moyale
# Processing Record 1 of Set 12 | saint-philippe
# Processing Record 2 of Set 12 | bata
# Processing Record 3 of Set 12 | ad dawadimi
# Processing Record 4 of Set 12 | nogliki
# Processing Record 5 of Set 12 | nhamunda
# Processing Record 6 of Set 12 | kutum
# Processing Record 7 of Set 12 | jand
# Processing Record 8 of Set 12 | richmond
# Processing Record 9 of Set 12 | ovalle
# Processing Record 10 of Set 12 | muromtsevo
# Processing Record 11 of Set 12 | nouadhibou
# Processing Record 12 of Set 12 | ginir
# Processing Record 13 of Set 12 | aweil
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          547
# Lat           547
# Lng           547
# Max Temp      547
# Humidity      547
# Cloudiness    547
# Wind Speed    547
# Country       547
# Date          547
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      6.84        95         100
# 1           waitangi -43.9535 -176.5597     11.57        77          76
# 2              lihue  21.9789 -159.3672     25.97        65           0
# 3          grytviken -54.2811  -36.5092      8.45        87         100
# 4            quellon -43.1167  -73.6167     11.18        89          99
#
#    Wind Speed Country        Date
# 0       18.99      TF  1732400778
# 1        4.92      NZ  1732400778
# 2        3.60      US  1732400794
# 3        6.32      GS  1732400775
# 4        0.60      CL  1732400865

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      6.84        95         100
# 1                 waitangi -43.9535 -176.5597     11.57        77          76
# 2                    lihue  21.9789 -159.3672     25.97        65           0
# 3                grytviken -54.2811  -36.5092      8.45        87         100
# 4                  quellon -43.1167  -73.6167     11.18        89          99
#
#          Wind Speed Country        Date
# City_ID
# 0             18.99      TF  1732400778
# 1              4.92      NZ  1732400778
# 2              3.60      US  1732400794
# 3              6.32      GS  1732400775
# 4              0.60      CL  1732400865

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df.loc[:,"Lat"], city_data_df.loc[:,"Max Temp"], facecolors = "blue", edgecolors= "black")

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Latitude vs. Max Temperature')
plt.grid(True)
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df.loc[:,"Lat"], city_data_df.loc[:,"Humidity"], facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df.loc[:,"Lat"], city_data_df.loc[:,"Cloudiness"], facecolors="blue", edgecolors="black" )

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs. Cloudiness')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df.loc[:,"Lat"], city_data_df.loc[:,"Wind Speed"], facecolor="blue", edgecolor="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regress_plot(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    regress_plot.line_eq = "y = " + str(round(slope,2)) + "x + " +str(round(intercept, 2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    print(f"The r-value is: {rvalue}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                           lihue  21.9789 -159.3672     25.97        65
# 5                          tibiri  13.5627    7.0485     22.69        18
# 6                       kurchatov  51.6601   35.6521     -1.18        85
# 9                          haenam  34.5711  126.5989      7.57        62
# 11       petropavlovsk-kamchatsky  53.0452  158.6483     -6.67        73
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                 0        3.60      US  1732400794
# 5                11        4.25      NE  1732400865
# 6               100        6.56      RU  1732400865
# 9                98        1.87      KR  1732400865
# 11               75        2.00      RU  1732400781

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      6.84        95         100
# 1                 waitangi -43.9535 -176.5597     11.57        77          76
# 3                grytviken -54.2811  -36.5092      8.45        87         100
# 4                  quellon -43.1167  -73.6167     11.18        89          99
# 7                bulakamba  -6.8748  108.9559     26.34        82         100
#
#          Wind Speed Country        Date
# City_ID
# 0             18.99      TF  1732400778
# 1              4.92      NZ  1732400778
# 3              6.32      GS  1732400775
# 4              0.60      CL  1732400865
# 7              3.08      ID  1732400655

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
regress_plot(northern_hemi_df.loc[:, "Lat"], northern_hemi_df.loc[:,"Max Temp"])
plt.annotate(regress_plot.line_eq, (2,4), fontsize=15, color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Northern Hemisphere")
plt.show()
# Out:
# The r-value is: -0.8555103642277584

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
